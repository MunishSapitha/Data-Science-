# %%
# import library

import pandas as pd

# %%
# load dataset

dataset=pd.read_csv("kidney_disease.csv")
dataset
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %% [markdown]
# # Qualitative and Quantitative Data

# %%
# Qualitative and Quantitative Data
# Categorical and Numerical data

qual=[]
quan=[]
for columnName in dataset.columns:
    if(dataset[columnName].dtypes=='O'):
        qual.append(columnName)
    else:
        quan.append(columnName)

# %%
qual
# Out:
# ['rbc',
#  'pc',
#  'pcc',
#  'ba',
#  'pcv',
#  'wc',
#  'rc',
#  'htn',
#  'dm',
#  'cad',
#  'appet',
#  'pe',
#  'ane',
#  'classification']

# %%
quan
# Out:
# ['id', 'age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo']

# %% [markdown]
# # Mean, Median, Mode

# %%
dataset.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# ...

# %%
# Create Table - DataFrame

descriptive=pd.DataFrame()
descriptive
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Create Index - Row Name

descriptive=pd.DataFrame(index=["Mean","Median","Mode"])
descriptive
# Out:
# Empty DataFrame
# Columns: []
# Index: [Mean, Median, Mode]

# %%
# Create columns - column Name

descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)
descriptive
# Out:
#          id  age   bp   sg   al   su  bgr   bu   sc  sod  pot hemo
# Mean    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Median  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Mode    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
# Calculate Mean, Median, Mode for Quantitative Data
# Mean - Average Value
# Median - Midpoint Value
# Mode - Most repeated value

descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
descriptive
# Out:
#            id        age         bp        sg        al        su         bgr  \
# Mean    199.5  51.483376  76.469072  1.017408  1.016949  0.450142  148.036517
# Median  199.5       55.0       80.0      1.02       0.0       0.0       121.0
# Mode        0       60.0       80.0      1.02       0.0       0.0        99.0
#
#                bu        sc         sod       pot       hemo
# Mean    57.425722  3.072454  137.528754  4.627244  12.526437
# Median       42.0       1.3       138.0       4.4      12.65
# Mode         46.0       1.2       135.0       3.5       15.0

# %% [markdown]
# # Percentile

# %%
# Percentile

import numpy as np

# %%
np.percentile(dataset["id"],50)
# Out:
# 199.5

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%","99%"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
        
descriptive
# Out:
#              id        age         bp        sg        al        su  \
# Mean      199.5  51.483376  76.469072  1.017408  1.016949  0.450142
# Median    199.5       55.0       80.0      1.02       0.0       0.0
# Mode          0       60.0       80.0      1.02       0.0       0.0
# Q1:25%    99.75       42.0       70.0      1.01       0.0       0.0
# Q2:50%    199.5       55.0       80.0      1.02       0.0       0.0
# Q3:75%   299.25       64.5       80.0      1.02       2.0       0.0
# Q4:100%   399.0       90.0      180.0     1.025       5.0       5.0
# 99%      395.01        NaN        NaN       NaN       NaN       NaN
#
#                 bgr         bu        sc         sod       pot       hemo
# Mean     148.036517  57.425722  3.072454  137.528754  4.627244  12.526437
# Median        121.0       42.0       1.3       138.0       4.4      12.65
# Mode           99.0       46.0       1.2       135.0       3.5       15.0
# ...

# %% [markdown]
# # Inter Quartile Range

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%","99%","IQR","1.5*IQR","Lesser","Greater","min","max"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
    
    descriptive[columnName]["IQR"]= descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
    descriptive[columnName]["1.5*IQR"]=1.5*descriptive[columnName]["IQR"]
    descriptive[columnName]["Lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5*IQR"]
    descriptive[columnName]["Greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5*IQR"]
    descriptive[columnName]["min"]=dataset[columnName].min()
    descriptive[columnName]["max"]=dataset[columnName].max()
        
descriptive
# Out:
#              id        age         bp        sg        al        su  \
# Mean      199.5  51.483376  76.469072  1.017408  1.016949  0.450142
# Median    199.5       55.0       80.0      1.02       0.0       0.0
# Mode          0       60.0       80.0      1.02       0.0       0.0
# Q1:25%    99.75       42.0       70.0      1.01       0.0       0.0
# Q2:50%    199.5       55.0       80.0      1.02       0.0       0.0
# Q3:75%   299.25       64.5       80.0      1.02       2.0       0.0
# Q4:100%   399.0       90.0      180.0     1.025       5.0       5.0
# 99%      395.01        NaN        NaN       NaN       NaN       NaN
# IQR       199.5       22.5       10.0      0.01       2.0       0.0
# 1.5*IQR  299.25      33.75       15.0     0.015       3.0       0.0
# Lesser   -199.5       8.25       55.0     0.995      -3.0       0.0
# Greater   598.5      98.25       95.0     1.035       5.0       0.0
# min           0        2.0       50.0     1.005       0.0       0.0
# ...

# %% [markdown]
# # Finding Outlier Column

# %%
lesser=[]
greater=[]

for columnName in quan:
    if(descriptive[columnName]["min"]<descriptive[columnName]["Lesser"]):
        lesser.append(columnName)
    if(descriptive[columnName]["max"]>descriptive[columnName]["Greater"]):
        greater.append(columnName)

# %%
lesser
# Out:
# ['age', 'bp', 'sod', 'hemo']

# %%
greater
# Out:
# ['bp', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot']

# %% [markdown]
# # Replacing Lesser and Greater outlier values to Potential Outliers

# %%
for columnName in lesser:
    dataset[columnName][dataset[columnName]<descriptive[columnName]["Lesser"]]=descriptive[columnName]["Lesser"]
for columnName in greater:
    dataset[columnName][dataset[columnName]>descriptive[columnName]["Greater"]]=descriptive[columnName]["Greater"]
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10456\716799018.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[columnName][dataset[columnName]<descriptive[columnName]["Lesser"]]=descriptive[columnName]["Lesser"]
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10456\716799018.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[columnName][dataset[columnName]<descriptive[columnName]["Lesser"]]=descriptive[columnName]["Lesser"]
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10456\716799018.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%","99%","IQR","1.5*IQR","Lesser","Greater","min","max"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
    
    descriptive[columnName]["IQR"]= descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
    descriptive[columnName]["1.5*IQR"]=1.5*descriptive[columnName]["IQR"]
    descriptive[columnName]["Lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5*IQR"]
    descriptive[columnName]["Greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5*IQR"]
    descriptive[columnName]["min"]=dataset[columnName].min()
    descriptive[columnName]["max"]=dataset[columnName].max()
        
descriptive
# Out:
#              id        age         bp        sg        al   su        bgr  \
# Mean      199.5  51.551151  75.695876  1.017408  1.016949  0.0  139.97191
# Median    199.5       55.0       80.0      1.02       0.0  0.0      121.0
# Mode          0       60.0       80.0      1.02       0.0  0.0      259.0
# Q1:25%    99.75       42.0       70.0      1.01       0.0  0.0       99.0
# Q2:50%    199.5       55.0       80.0      1.02       0.0  0.0      121.0
# Q3:75%   299.25       64.5       80.0      1.02       2.0  0.0      163.0
# Q4:100%   399.0       90.0       95.0     1.025       5.0  0.0      259.0
# 99%      395.01        NaN        NaN       NaN       NaN  NaN        NaN
# IQR       199.5       22.5       10.0      0.01       2.0  0.0       64.0
# 1.5*IQR  299.25      33.75       15.0     0.015       3.0  0.0       96.0
# Lesser   -199.5       8.25       55.0     0.995      -3.0  0.0        3.0
# Greater   598.5      98.25       95.0     1.035       5.0  0.0      259.0
# ...

# %%
lesser=[]
greater=[]

for columnName in quan:
    if(descriptive[columnName]["min"]<descriptive[columnName]["Lesser"]):
        lesser.append(columnName)
    if(descriptive[columnName]["max"]>descriptive[columnName]["Greater"]):
        greater.append(columnName)

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# []

# %%
#Finally, no outlier values in dataset
